# %%
import openai
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# %%
openai.api_key = ''

# %%
#Texto en GPT-3
def generar_texto(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=150
    )
    return response.choices[0].text.strip()

# %%
#Imagen en DALL-E
def generar_imagen(prompt):
    response = openai.Image.create(
        prompt=prompt,
        n=1,
        size="512x512"
    )
    image_url = response['data'][0]['url']
    return Image.open(BytesIO(requests.get(image_url).content))

# %%
#Generar una historia corta
prompt_historia = "Escribe una historia corta y emotiva desde la perspectiva de un perro callejero, destacando los desafíos que enfrenta diariamente."
historia = generar_texto(prompt_historia)
print(historia)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[23], line 3
#       1 #Generar una historia corta
#       2 prompt_historia = "Escribe una historia corta y emotiva desde la perspectiva de un perro callejero, destacando los desafíos que enfrenta diariamente."
# ----> 3 historia = generar_texto(prompt_historia)
#       4 print(historia)
#
# Cell In[21], line 3, in generar_texto(prompt)
#       2 def generar_texto(prompt):
# ----> 3     response = openai.Completion.create(
#       4         engine="text-davinci-002",
#       5         prompt=prompt,
#       6         max_tokens=150
#       7     )
#       8     return response.choices[0].text.strip()
#
# File ~\miniconda3\envs\generacion-de-prompts\lib\site-packages\openai\api_resources\completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ...

# %%
#Generar razones para adoptar
prompt_razones = "Genera una lista de 5 razones convincentes por las que adoptar un perro callejero es mejor que comprar uno de raza."
razones = generar_texto(prompt_razones)
print(razones)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[24], line 3
#       1 #Generar razones para adoptar
#       2 prompt_razones = "Genera una lista de 5 razones convincentes por las que adoptar un perro callejero es mejor que comprar uno de raza."
# ----> 3 razones = generar_texto(prompt_razones)
#       4 print(razones)
#
# Cell In[21], line 3, in generar_texto(prompt)
#       2 def generar_texto(prompt):
# ----> 3     response = openai.Completion.create(
#       4         engine="text-davinci-002",
#       5         prompt=prompt,
#       6         max_tokens=150
#       7     )
#       8     return response.choices[0].text.strip()
#
# File ~\miniconda3\envs\generacion-de-prompts\lib\site-packages\openai\api_resources\completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ...

# %%
#Generar una imagen
prompt_imagen = "Crea una imagen realista y conmovedora de un perro cachorro triste buscando comida en un tacho de basura de una ciudad con un fondo urbano difuminado"
imagen = generar_imagen(prompt_imagen)
plt.imshow(imagen)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[25], line 3
#       1 #Generar una imagen
#       2 prompt_imagen = "Crea una imagen realista y conmovedora de un perro cachorro triste buscando comida en un tacho de basura de una ciudad con un fondo urbano difuminado"
# ----> 3 imagen = generar_imagen(prompt_imagen)
#       4 plt.imshow(imagen)
#       5 plt.axis('off')
#
# Cell In[22], line 3, in generar_imagen(prompt)
#       2 def generar_imagen(prompt):
# ----> 3     response = openai.Image.create(
#       4         prompt=prompt,
#       5         n=1,
#       6         size="512x512"
#       7     )
#       8     image_url = response['data'][0]['url']
#       9     return Image.open(BytesIO(requests.get(image_url).content))
#
# ...

# %%
#Generar consejos para cuidar a un perro adoptado
prompt_consejos = "Proporciona 5 consejos prácticos para cuidar a un perro recién adoptado de la calle."
consejos = generar_texto(prompt_consejos)
print(consejos)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[18], line 3
#       1 #Generar consejos para cuidar a un perro adoptado
#       2 prompt_consejos = "Proporciona 5 consejos prácticos para cuidar a un perro recién adoptado de la calle."
# ----> 3 consejos = generar_texto(prompt_consejos)
#       4 print(consejos)
#
# Cell In[13], line 3, in generar_texto(prompt)
#       2 def generar_texto(prompt):
# ----> 3     response = openai.Completion.create(
#       4         engine="text-davinci-003",
#       5         prompt=prompt,
#       6         max_tokens=150
#       7     )
#       8     return response.choices[0].text.strip()
#
# File ~\miniconda3\envs\generacion-de-prompts\lib\site-packages\openai\api_resources\completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
# ...
